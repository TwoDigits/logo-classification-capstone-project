# %% [markdown]
# # Capstone Project of the Machine Learning Engineer Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Logo Classification App
#
# ---
# ### Why We're Here
#
# In this notebook, we make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, our code will accept any user-supplied image as input.  If a logo is detected in the image, it will provide an estimate of the brand.
#
# ![Sample Logo Output](samples.jpg)
#
# In this real-world setting, we need to piece together a series of models to perform different tasks; for instance, the algorithm that detects logos in an image will be different from the CNN that infers the brand.
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Data Preprocessing
# * [Step 1](#step1): Implementation
# * [Step 2](#step2): Refinement
# * [Step 3](#step3): Model Evaluation and Validation
#
# ---
# <a id='step0'></a>
# ## Step 0: Data Preprocessing
#
# ### Import the Logos in the Wild Dataset
#
# In the code cell below, we import a dataset of logo images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `brand_names` - list of string-valued brand names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob
import re

pattern = re.compile("img[0-9]+.jpg")

# define function to load train, test, and validation datasets
def load_jpg_dataset(path):
    data = load_files(path)
    logo_files = np.array(data['filenames'])
    indices_of_jpegs = [i for i, j in enumerate(logo_files) if 'jpg'==j.split('.')[-1]]
    logo_targets = np_utils.to_categorical(np.array(data['target']), max(data['target']+1))
    return logo_files[indices_of_jpegs], logo_targets[indices_of_jpegs]

# load train, test, and validation datasets
all_files, all_targets = load_jpg_dataset('LogosInTheWild-v2/data/voc_format')

# load list of brand names
brand_names = [item.split('/')[-2] for item in (glob("LogosInTheWild-v2/data/voc_format/*/"))]


print("brand names: ",brand_names)
# print statistics about the dataset
print('There are %d total brand categories.' % len(brand_names))
print('There are %d JPEG images with logos.' % len(all_files))
# Out:
# brand names:  ['FedEx', 'budweiser', 'aspirin', 'azeca', 'bello digital', 'airhawk', 'chanel', 'caterpillar', 'rolex', 'toyota', 'athalon', 'Samsung', 'aquapac', 'verizon', 'LOreal', 'American Express', 'BMW', 'boeing', 'sony', 'santander', 'McDonalds', 'panasonic', 'nescafe', 'hershey', 'gucci', 'shell', 'porsche', 'colgate', 'huawei', 'chevrolet', 'bionade', 'nivea', 'bosch', 'costco', 'kia', 'honda', 'uniqlo', 'visa', 'ford', 'ben sherman', 'burger king', 'lego', 'pizza hut', 'bank of america', 'frito lays', 'amcrest', 'netflix', 'hp', 'Pampers', 'heineken', 'wells fargo', 'nestle', 'nike', 'abus', 'hsbc', 'starbucks', 'kraft', 'aral', 'pepsi', 'home depot', 'allett', 'bem wireless', 'aluratek', 'mercedes benz', 'ape', 'axa', 'accenture', 'subway', 'allianz', 'esso', 'CVS', 'IBM', 'apc', 'armitron', 'lexus', 'tmobile', 'benrus', 'danone', 'canon', 'philips', 'UPS', 'louis vuitton', 'cisco', 'cartier', 'gillette', 'amazon', 'red bull', 'hyundai', 'coca-cola', 'nissan', 'bella taylo
# ...

# %%
from sklearn.model_selection import train_test_split

#train_files, test_files, train_targets, test_targets = train_test_split(all_files, all_targets, test_size=0.4, random_state=0)
train_and_val_files, test_files, train_and_val_targets, test_targets = train_test_split(all_files, all_targets, test_size=0.2, random_state=0)
train_files, val_files, train_targets, val_targets = train_test_split(train_and_val_files, train_and_val_targets, test_size=0.2, random_state=0)

from sklearn.model_selection import ShuffleSplit
n_samples = train_files.shape[0]
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

print(train_files.shape)
print(train_targets.shape)
# Out:
# (6033,)
# (6033, 109)

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
val_tensors = paths_to_tensor(val_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# ...
# 100%|██████████| 1886/1886 [00:27<00:00, 69.33it/s]

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Implementation
#
# ### Create a CNN to Classify Logos (from Scratch)
#
# Now we want a way to predict logo brands from images.  In this step, you will create a CNN that classifies logos.
#
# We do not add too many trainable layers as more parameters mean longer training and we do not have a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take.
#
# We mention that the task of classifying small logos in images is considered exceptionally challenging.

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint  

checkpointer = ModelCheckpoint(filepath='saved_keras_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model_from_scratch = Sequential()

model_from_scratch.add(Conv2D (kernel_size = (2,2), filters = 32, input_shape=train_tensors.shape[1:], activation='relu',data_format="channels_last"))
model_from_scratch.add(MaxPooling2D(pool_size=2, strides=2))
model_from_scratch.add(Conv2D (kernel_size = 2, filters = 64, activation='relu'))
model_from_scratch.add(MaxPooling2D(pool_size = 2, strides=2))
model_from_scratch.add(GlobalAveragePooling2D(data_format=None))
model_from_scratch.add(Dense(109, activation = 'softmax'))
 
model_from_scratch.summary()

#Compile the model

model_from_scratch.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

epochs = 20

#train the model
H = model_from_scratch.fit(train_tensors, train_targets,  #validation_split=0.3,
          validation_data=(val_tensors, val_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)

#Load the model with the best validation loss
model_from_scratch.load_weights('saved_keras_models/weights.best.from_scratch.hdf5')

print('\n', 'Test accuracy of the model from scratch:', model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 109)               7085
# ...
# Total params: 15,757
# Trainable params: 15,757
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
#Load the model with the best validation loss
model_from_scratch.load_weights('saved_keras_models/weights.best.from_scratch.hdf5')

print('\n', 'Test accuracy of the model from scratch:', model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')

#train the model for 600 epochs
epochs = 600

H = model_from_scratch.fit(train_tensors, train_targets,  #validation_split=0.3,
          validation_data=(val_tensors, val_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)

#get the accuracy of the model from scratch on the test images
print('\n', 'Test accuracy of the model from scratch:', model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
#  Test accuracy of the model from scratch: 17.497348891272903 %.
# Train on 6033 samples, validate on 1509 samples
# Epoch 1/600
# 6033/6033 [==============================] - 17s 3ms/step - loss: 3.5761 - acc: 0.1784 - val_loss: 3.6837 - val_acc: 0.1643
#
# Epoch 00001: val_loss did not improve from 3.65549
# Epoch 2/600
# 6033/6033 [==============================] - 18s 3ms/step - loss: 3.5689 - acc: 0.1822 - val_loss: 3.6503 - val_acc: 0.1696
#
# Epoch 00002: val_loss improved from 3.65549 to 3.65025, saving model to saved_keras_models/weights.best.from_scratch.hdf5
# Epoch 3/600
# 6033/6033 [==============================] - 18s 3ms/step - loss: 3.5603 - acc: 0.1895 - val_loss: 3.6501 - val_acc: 0.1730
#
# Epoch 00003: val_loss improved from 3.65025 to 3.65008, saving model to saved_keras_models/weights.best.from_scratch.hdf5
# Epoch 4/600
# 6033/6033 [==============================] - 18s 3ms/step - loss: 3.5515 - acc: 0.1847 - val_loss: 3.6497 - val_acc: 0.1730
#
# ...

# %% [markdown]
# ### Define a Custom Model on Top of the VGG16 model to Classify Logos
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a convolutional layer, a max pooling layer, a global average pooling layer and a fully connected layer, where the latter contains one node for each logo category and is equipped with a softmax.

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import Conv2D,MaxPooling2D, Flatten,Dense,Dropout,GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint  

VGG16_model = VGG16(include_top=True, weights='imagenet', input_shape=train_tensors.shape[1:])
print(VGG16_model.summary())

# Creating dictionary that maps layer names to the layers
layer_dict = dict([(layer.name, layer) for layer in VGG16_model.layers])

# Getting output tensor of the last VGG layer that we want to include
x = layer_dict['block5_pool'].output

# Stacking a new simple convolutional network on top of it    
#x=GlobalAveragePooling2D()(x)
x = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
#x = Flatten()(x)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(109, activation='softmax')(x)

# Creating new model. Please note that this is NOT a Sequential() model.
from keras.models import Model
custom_model = Model(input=VGG16_model.input, output=x)

# Make sure that the pre-trained bottom layers are not trainable
for layer in custom_model.layers[:19]:
    layer.trainable = False

custom_model.summary()

#compile the model
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
custom_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

#train the custom model
epochs = 20

checkpointer2 = ModelCheckpoint(filepath='saved_keras_models/weights.best.custom.hdf5', 
                               verbose=1, save_best_only=True)
#custom_model.load_weights('saved_keras_models/weights.best.custom.hdf5')
#VGG16_model.fit(train_tensors, train_targets, validation_split=0.2,epochs=10, batch_size=20, callbacks=[checkpointer3], verbose=1)
H2 = custom_model.fit(train_tensors, train_targets, validation_data=(val_tensors, val_targets),epochs=epochs, batch_size=32, callbacks=[checkpointer2], verbose=1)

#Load the custom model with the best Validation Loss
custom_model.load_weights('saved_keras_models/weights.best.custom.hdf5')

#get the accuracy of the custom model on the test images
print('\n', 'Test accuracy of the custom model on top of VGG16:', custom_model.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
#Load the model with the best validation loss
custom_model.load_weights('saved_keras_models/weights.best.custom.hdf5')

#train the model for 600 epochs
epochs = 600

H22 = custom_model.fit(train_tensors, train_targets,  #validation_split=0.3,
          validation_data=(val_tensors, val_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer2], verbose=1)

#Load the model with the best validation loss
custom_model.load_weights('saved_keras_models/weights.best.custom.hdf5')

#get the accuracy of the model from scratch on the test images
print('\n', 'Test accuracy of the custom model on top of VGG16:', custom_model.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# Train on 6033 samples, validate on 1509 samples
# Epoch 1/600
# 6033/6033 [==============================] - 96s 16ms/step - loss: 2.4716 - acc: 0.3599 - val_loss: 2.8355 - val_acc: 0.3559
#
# Epoch 00001: val_loss did not improve from 2.80814
# Epoch 2/600
# 6033/6033 [==============================] - 91s 15ms/step - loss: 2.3930 - acc: 0.3726 - val_loss: 3.0923 - val_acc: 0.3254
#
# Epoch 00002: val_loss did not improve from 2.80814
# Epoch 3/600
# 6033/6033 [==============================] - 91s 15ms/step - loss: 2.3377 - acc: 0.3942 - val_loss: 2.9348 - val_acc: 0.3360
#
# Epoch 00003: val_loss did not improve from 2.80814
# Epoch 4/600
# 6033/6033 [==============================] - 91s 15ms/step - loss: 2.3335 - acc: 0.3829 - val_loss: 2.9633 - val_acc: 0.3419
#
# Epoch 00004: val_loss did not improve from 2.80814
# Epoch 5/600
# 6033/6033 [==============================] - 91s 15ms/step - loss: 2.2694 - acc: 0.4020 - val_loss: 2.9867 - val_acc: 0.3307
#
# ...

# %%
#Load the model with the best validation loss
custom_model.load_weights('saved_keras_models/weights.best.custom.hdf5')

#get the accuracy of the model from scratch on the test images
print('\n', 'Test accuracy of the custom model on top of VGG16:', custom_model.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
#  Test accuracy of the custom model on top of VGG16: 36.797454943712545 %.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2:  Refinement

# %% [markdown]
# ### Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True, # randomly flip images horizontally
    vertical_flip=True, # randomly flip images vertically
    rotation_range=90)

# create and configure augmented image generator
datagen_valid = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True, # randomly flip images horizontally
    vertical_flip=True, # randomly flip images vertically
    rotation_range=90)

# fit augmented image generator on data
datagen_train.fit(train_tensors)
datagen_valid.fit(val_tensors)

# %% [markdown]
# ### Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
train_tensors_subset = train_tensors[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(train_tensors_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(train_tensors_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.savefig('original_images.jpg')

plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(train_tensors_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.savefig('augmented_images.jpg')
    plt.show()
    break;

# %% [markdown]
# ### Train the first model from scratch on the augmented images and test it

# %%
from keras.callbacks import ModelCheckpoint   

checkpointer3 = ModelCheckpoint(filepath='saved_keras_models/aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)

model_from_scratch.summary()

#Compile the second model from scratch
model_from_scratch.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

#Load the weights with the best validation loss
model_from_scratch.load_weights('saved_keras_models/weights.best.from_scratch.hdf5')


# train the model
batch_size = 20
epochs = 50

H3 = model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer3],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

model_from_scratch.load_weights('saved_keras_models/aug_model.weights.best.hdf5')
print('\n', 'Test accuracy of the model from scratch:', model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 109)               7085
# ...
# Total params: 15,757
# Trainable params: 15,757
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# ...

# %% [markdown]
# ### Train the custom model on top of VGG16 on the augmented images and test it
#
# This is particularly interesting, as the custom model clearly overfitted when it is trained on the original images alone.

# %%
from keras.callbacks import ModelCheckpoint   


checkpointer4 = ModelCheckpoint(filepath='saved_keras_models/weights.best.aug_custom.hdf5', 
                               verbose=1, save_best_only=True)

custom_model.load_weights('saved_keras_models/weights.best.custom.hdf5')

#train the custom model 
batch_size = 20
epochs = 50
H4 = custom_model.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer4],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

#load the model weights with best validation loss
custom_model.load_weights('saved_keras_models/weights.best.aug_custom.hdf5')

#get the accuracy of the trained model on the test images
print('\n', 'Test accuracy of custom model:', custom_model.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# Epoch 1/50
# 301/301 [==============================] - 92s 304ms/step - loss: 3.7612 - acc: 0.1468 - val_loss: 3.4633 - val_acc: 0.2107
#
# Epoch 00001: val_loss improved from inf to 3.46333, saving model to saved_keras_models/weights.best.aug_custom.hdf5
# Epoch 2/50
# 301/301 [==============================] - 90s 299ms/step - loss: 3.6635 - acc: 0.1614 - val_loss: 3.4549 - val_acc: 0.2216
#
# Epoch 00002: val_loss improved from 3.46333 to 3.45493, saving model to saved_keras_models/weights.best.aug_custom.hdf5
# Epoch 3/50
# 301/301 [==============================] - 90s 299ms/step - loss: 3.6512 - acc: 0.1736 - val_loss: 3.4509 - val_acc: 0.2169
#
# Epoch 00003: val_loss improved from 3.45493 to 3.45093, saving model to saved_keras_models/weights.best.aug_custom.hdf5
# Epoch 4/50
# 301/301 [==============================] - 90s 300ms/step - loss: 3.6537 - acc: 0.1682 - val_loss: 3.4544 - val_acc: 0.2317
#
# Epoch 00004: val_loss did not improve from 3.45093
# Epoch 5/50
# ...

# %%
#load the model weights with best validation loss
custom_model.load_weights('saved_keras_models/weights.best.aug_custom.hdf5')

#get the accuracy of the trained model on the test images
print('\n', 'Test accuracy of custom model:', custom_model.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
#  Test accuracy of custom model: 28.10180275873819 %.

# %%
from keras.callbacks import ModelCheckpoint   


checkpointer4 = ModelCheckpoint(filepath='saved_keras_models/weights.best.aug_custom.hdf5', 
                               verbose=1, save_best_only=True)

custom_model.load_weights('saved_keras_models/weights.best.aug_custom.hdf5')

#train the custom model now with a large batch size
batch_size = 128
epochs = 20
H42 = custom_model.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer4],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

#load the model weights with best validation loss
custom_model.load_weights('saved_keras_models/weights.best.aug_custom.hdf5')

#get the accuracy of the trained model on the test images
print('\n', 'Test accuracy of custom model:', custom_model.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# Epoch 1/20
# 47/47 [==============================] - 77s 2s/step - loss: 3.5417 - acc: 0.1882 - val_loss: 3.4124 - val_acc: 0.2379
#
# Epoch 00001: val_loss improved from inf to 3.41240, saving model to saved_keras_models/weights.best.aug_custom.hdf5
# Epoch 2/20
# 47/47 [==============================] - 72s 2s/step - loss: 3.4896 - acc: 0.1881 - val_loss: 3.3883 - val_acc: 0.2419
#
# Epoch 00002: val_loss improved from 3.41240 to 3.38831, saving model to saved_keras_models/weights.best.aug_custom.hdf5
# Epoch 3/20
# 47/47 [==============================] - 64s 1s/step - loss: 3.4777 - acc: 0.1966 - val_loss: 3.3985 - val_acc: 0.2317
#
# Epoch 00003: val_loss did not improve from 3.38831
# Epoch 4/20
# 47/47 [==============================] - 63s 1s/step - loss: 3.4774 - acc: 0.1890 - val_loss: 3.3566 - val_acc: 0.2390
#
# Epoch 00004: val_loss improved from 3.38831 to 3.35663, saving model to saved_keras_models/weights.best.aug_custom.hdf5
# Epoch 5/20
# ...

# %% [markdown]
# ### Extend the first model from scratch to achieve more complexity for higher accuracy

# %%
from keras.models import Model

model_from_scratch.load_weights('saved_keras_models/aug_model.weights.best.hdf5')


# Creating dictionary that maps layer names to the layers
layer_dict = dict([(layer.name, layer) for layer in model_from_scratch.layers])

# Getting output tensor of the last VGG layer that we want to include
x = layer_dict['max_pooling2d_8'].output

# Stacking a new simple convolutional network on top of it    
#x=GlobalAveragePooling2D()(x)
x = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(filters=64, kernel_size=(2, 2), activation='relu')(x)
x = MaxPooling2D(pool_size=(3, 3))(x)
x = Dropout(0.3)(x)
x = Conv2D(filters=32, kernel_size=(2, 2), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(filters=64, kernel_size=(2, 2), activation='relu')(x)
#x = Flatten()(x)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(109, activation='softmax')(x)

# Creating new model. Please note that this is NOT a Sequential() model.
extended_model_from_scratch = Model(input=model_from_scratch.input, output=x)

# We leave the first layers from the model from scratch trainable
for layer in model_from_scratch.layers[:4]:
    layer.trainable = True

extended_model_from_scratch.summary()
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d07362c863ec> in <module>
#       1 from keras.models import Model
#       2
# ----> 3 model_from_scratch.load_weights('saved_keras_models/aug_model.weights.best.hdf5')
#       4
#       5
#
# NameError: name 'model_from_scratch' is not defined

# %% [markdown]
# ### Train the extended model from scratch with optimizer RMSprop and batch size 32 and test it

# %%
#Compile the second model from scratch
extended_model_from_scratch.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

batch_size = 32
epochs = 50

# train the model
checkpointer5 = ModelCheckpoint(filepath='saved_keras_models/aug_extended_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
#extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model.weights.best.hdf5')

H5 = extended_model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer5],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model.weights.best.hdf5')
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# Epoch 1/50
# 188/188 [==============================] - 74s 393ms/step - loss: 4.5057 - acc: 0.0399 - val_loss: 4.2978 - val_acc: 0.0625
#
# Epoch 00001: val_loss improved from inf to 4.29778, saving model to saved_keras_models/aug_extended_model.weights.best.hdf5
# Epoch 2/50
# 188/188 [==============================] - 72s 383ms/step - loss: 4.2608 - acc: 0.0754 - val_loss: 4.1616 - val_acc: 0.1036
#
# Epoch 00002: val_loss improved from 4.29778 to 4.16162, saving model to saved_keras_models/aug_extended_model.weights.best.hdf5
# Epoch 3/50
# 188/188 [==============================] - 70s 375ms/step - loss: 4.0906 - acc: 0.0954 - val_loss: 4.0305 - val_acc: 0.1043
#
# Epoch 00003: val_loss improved from 4.16162 to 4.03055, saving model to saved_keras_models/aug_extended_model.weights.best.hdf5
# Epoch 4/50
# 188/188 [==============================] - 71s 376ms/step - loss: 3.9341 - acc: 0.1218 - val_loss: 3.8675 - val_acc: 0.1131
#
# ...

# %% [markdown]
# ### Train now the extended model from scratch with optimizer adam and batch size 64

# %%
#Display the model architecture
extended_model_from_scratch.summary()

checkpointer6 = ModelCheckpoint(filepath='saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5', 
                               verbose=1, save_best_only=True)

#compile model with optimizer adam insted of RMSprop
extended_model_from_scratch.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model.weights.best.hdf5')

#train model with different batch size
batch_size = 64
epochs = 30

H6 = extended_model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer6],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

#load the model weights with best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')

#get the accuracy of the trained model on the test images
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7_input (InputLayer)  (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 53, 53, 32)        18464
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 26, 26, 32)        0
# ...

# %% [markdown]
# ### Train now the extended model from scratch with optimizer Adagrad and batch size 64

# %%
#Display the model architecture
extended_model_from_scratch.summary()

#compile the model
extended_model_from_scratch.compile(loss='categorical_crossentropy', optimizer='Adagrad', 
                  metrics=['accuracy'])

#load the weights with the best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model.weights.best.hdf5')


checkpointer7 = ModelCheckpoint(filepath='saved_keras_models/aug_extended_model_with_optimizer_adagrad.weights.best.hdf5', 
                               verbose=1, save_best_only=True)

#train the model
batch_size = 64
epochs = 30
H7 = extended_model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer7],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

#load the model weigths with the best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adagrad.weights.best.hdf5')

#get accuracy on the test images
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7_input (InputLayer)  (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 53, 53, 32)        18464
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 26, 26, 32)        0
# ...

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), H7.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H7.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H7.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), H7.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")
plt.show()

# %%
#Display the model architecture
extended_model_from_scratch.summary()

checkpointer6 = ModelCheckpoint(filepath='saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5', 
                               verbose=1, save_best_only=True)

#compile model with optimizer adam insted of RMSprop
extended_model_from_scratch.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')

#train model with different batch size
batch_size = 64
epochs = 600

H62 = extended_model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer6],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

#load the model weights with best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')

#get the accuracy of the trained model on the test images
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7_input (InputLayer)  (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 53, 53, 32)        18464
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 26, 26, 32)        0
# ...

# %%
#load the model weights with best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')

#get the accuracy of the trained model on the test images
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
#  Test accuracy of the extended model from scratch: 31.177094401762062 %.

# %%
epochs = 600
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), H62.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H62.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H62.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), H62.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-9a8c85a3f04e> in <module>()
#       4 plt.figure()
#       5 N = epochs
# ----> 6 plt.plot(np.arange(0, N), H62.history["loss"], label="train_loss")
#       7 plt.plot(np.arange(0, N), H62.history["val_loss"], label="val_loss")
#       8 plt.plot(np.arange(0, N), H62.history["acc"], label="train_acc")
#
# NameError: name 'H62' is not defined

# %% [markdown]
# ### Using GridSearch to find optimal parameters for our first model from scratch

# %%
import numpy
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
# Function to create model, required for KerasClassifier
def create_model(epochs=20,optimizer='RMSprop',activation='relu'):
    # create model
    model = Sequential()
    model.add(Conv2D (kernel_size = (2,2), filters = 32, input_shape=train_tensors.shape[1:], activation='relu',data_format="channels_last"))
    model.add(MaxPooling2D(pool_size=2, strides=2))
    model.add(Conv2D (kernel_size = 2, filters = 64, activation=activation))
    model.add(MaxPooling2D(pool_size = 2, strides=2))
    model.add(GlobalAveragePooling2D(data_format=None))
    model.add(Dense(109, activation = activation))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    #model.load_weights('saved_keras_models/aug_model.weights.best.hdf5')

    return model
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# create model
model = KerasClassifier(build_fn=create_model, verbose=1)
# define the grid search parameters
batch_size = [16, 32, 64]
epochs = [20]
optimizer = ['Adagrad', 'RMSprop', 'Adam']
activation = ['softmax', 'relu', 'tanh']
param_grid = dict(batch_size=batch_size, epochs=epochs,optimizer=optimizer,activation=activation)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1,verbose=2)

checkpointer8 = ModelCheckpoint(filepath='saved_keras_models/weights.best.from_scratch.hdf5', 
                               verbose=2, save_best_only=True)

H8 = grid.fit(train_tensors, train_targets,  
          epochs=epochs, batch_size=batch_size, callbacks=[checkpointer8], verbose=2)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV] activation=softmax, batch_size=16, epochs=20, optimizer=Adagrad .
# [CV] activation=softmax, batch_size=16, epochs=20, optimizer=Adagrad .
# [CV] activation=softmax, batch_size=16, epochs=20, optimizer=Adagrad .
# [CV] activation=softmax, batch_size=16, epochs=20, optimizer=RMSprop .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-fb2662669dce> in <module>()
#      36
#      37 grid.fit(train_tensors, train_targets,
# ---> 38           epochs=epochs, batch_size=batch_size, callbacks=[checkpointer], verbose=2)
#      39
#      40 # summarize results
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
# ...

# %% [markdown]
# ### Continue to train the first model from scratch with optimizer RMSprop and batch size 20

# %%
from keras.callbacks import ModelCheckpoint   

checkpointer3 = ModelCheckpoint(filepath='saved_keras_models/aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)

model_from_scratch.summary()

#Compile the second model from scratch
model_from_scratch.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

#Load the weights with the best validation loss
model_from_scratch.load_weights('saved_keras_models/aug_model.weights.best.hdf5')


# train the model
batch_size = 20
epochs = 50

H32 = model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer3],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

model_from_scratch.load_weights('saved_keras_models/aug_model.weights.best.hdf5')
print('\n', 'Test accuracy of the model from scratch:', model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 109)               7085
# ...
# Total params: 15,757
# Trainable params: 15,757
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# ...

# %% [markdown]
# ### Continue to train the  extended model from scratch with optimizer Adagrad

# %%
#Display the model architecture
extended_model_from_scratch.summary()

#compile the model
extended_model_from_scratch.compile(loss='categorical_crossentropy', optimizer='Adagrad', 
                  metrics=['accuracy'])

#load the weights with the best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adagrad.weights.best.hdf5')


checkpointer7 = ModelCheckpoint(filepath='saved_keras_models/aug_extended_model_with_optimizer_adagrad.weights.best.hdf5', 
                               verbose=1, save_best_only=True)

#train the model
batch_size = 64
epochs = 30
H72 = extended_model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer7],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

#load the model weigths with the best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adagrad.weights.best.hdf5')

#get accuracy on the test images
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7_input (InputLayer)  (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 53, 53, 32)        18464
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 26, 26, 32)        0
# ...

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), H72.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H72.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H72.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), H72.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %%
#Display the model architecture
extended_model_from_scratch.summary()

#compile the model
extended_model_from_scratch.compile(loss='categorical_crossentropy', optimizer='Adagrad', 
                  metrics=['accuracy'])

#load the weights with the best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adagrad.weights.best.hdf5')


checkpointer7 = ModelCheckpoint(filepath='saved_keras_models/aug_extended_model_with_optimizer_adagrad.weights.best.hdf5', 
                               verbose=1, save_best_only=True)

#train the model
batch_size = 64
epochs = 100
H73 = extended_model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer7],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

#load the model weigths with the best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adagrad.weights.best.hdf5')

#get accuracy on the test images
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7_input (InputLayer)  (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 53, 53, 32)        18464
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 26, 26, 32)        0
# ...

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), H73.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H73.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H73.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), H73.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: Model Evaluation and Validation

# %%
#Display the model architecture
extended_model_from_scratch.summary()

#checkpointer6 = ModelCheckpoint(filepath='saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5', 
#                               verbose=1, save_best_only=True)

#load weights with the best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')
    
    
#compile model with optimizer adam insted of RMSprop
extended_model_from_scratch.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

#load weights with the best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')

#train model with batch size 64
batch_size = 64
epochs = 10

H63 = extended_model_from_scratch.fit_generator(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
                    steps_per_epoch=train_tensors.shape[0] // batch_size,
                    epochs=epochs, verbose=1, callbacks=[checkpointer6],
                    validation_data=datagen_valid.flow(val_tensors, val_targets, batch_size=batch_size),
                    validation_steps=val_tensors.shape[0] // batch_size)

#load the model weights with best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')

#get the accuracy of the trained model on the test images
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7_input (InputLayer)  (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 53, 53, 32)        18464
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 26, 26, 32)        0
# ...

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = 10
plt.plot(np.arange(0, N), H63.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H63.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H63.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), H63.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %% [markdown]
# ### Predict Brand with the Model

# %%
import cv2
import tensorflow as tf
from object_detection.utils import dataset_util
from lxml import etree
import matplotlib.pyplot as plt
# %matplotlib inline

#load the weights with best validation loss of the extended model from scratch with optimizer adam
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')

for j in range(100,110):
    full_path = test_files[j]
    # load color (BGR) image
    img = cv2.imread(full_path)

    xml_path = full_path.split('.')[-2]+'.xml'
    with tf.gfile.GFile(xml_path, 'r') as fid:
        xml_str = fid.read()
        xml_str = bytes(bytearray(xml_str, encoding = 'utf-8'))
        xml = etree.fromstring(xml_str)
        data = dataset_util.recursive_parse_xml_to_dict(xml)['annotation']
        width = int(data['size']['width'])
        height = int(data['size']['height'])
        xmin = []
        ymin = []
        xmax = []
        ymax = []
        #classes = []
        classes_text = []
        truncated = []
        poses = []
        difficult_obj = []

        if 'object' in data:
            for obj in data['object']:
                difficult = bool(int(obj['difficult']))
                if difficult:
                    continue
                difficult_obj.append(int(difficult))
                xmin.append(float(obj['bndbox']['xmin']))# / width)
                ymin.append(float(obj['bndbox']['ymin']))# / height)
                xmax.append(float(obj['bndbox']['xmax']))# / width)
                ymax.append(float(obj['bndbox']['ymax']))# / height)
                classes_text.append(obj['name'].encode('utf8'))
                #if (obj['name'] in label_map_dict.keys()):
                # classes.append(label_map_dict[obj['name']])
                #else:
                # print("WARNING",full_path)
                truncated.append(int(obj['truncated']))
                poses.append(obj['pose'].encode('utf8'))
                #print(xmin,ymin,xmax,ymax)
                # get bounding box for each logo
    for i in range(len(xmin)):
        # add bounding box to color image
        cv2.rectangle(img,(int(xmin[i]),int(ymin[i])),(int(xmax[i]),int(ymax[i])),(255,0,0),2)
        cv2.putText(img, str(classes_text[i]) , (int(xmin[i])-10,int(ymin[i])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)

    brand_prediction = brand_names[np.argmax(extended_model_from_scratch.predict(np.expand_dims(test_tensors[j], axis=0)))]
    
    # convert BGR image to RGB for plotting
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    #cv2.imshow("Image",cv_rgb)
    # display the image, along with bounding box
    cv2.imwrite('Prediction_is_'+brand_prediction+'_of_'+full_path,img)
    
    #print('Prediction is',brand_prediction,'of ',full_path)
    fig = plt.figure(figsize=(20,3))
    plt.imshow(cv_rgb)
    fig.suptitle('Prediction is '+brand_prediction+' of '+full_path, fontsize=10)
    #fig_path = 'Prediction_is_'+brand_prediction+'_of_'+full_path.split('/')[-2]+full_path.split('/')[-1]
    fig_path="prediction_of_test_file_"+str(j)
    plt.savefig(fig_path)
    plt.show()

# %%
#load the model weights with best validation loss
extended_model_from_scratch.load_weights('saved_keras_models/aug_extended_model_with_optimizer_adam.weights.best.hdf5')

#compile model with optimizer adam insted of RMSprop
extended_model_from_scratch.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

#get the accuracy of the trained model on the test images
print('\n', 'Test accuracy of the extended model from scratch:', extended_model_from_scratch.evaluate(test_tensors, test_targets, verbose=0)[1]*100,'%.')
# Out:
#  Test accuracy of the extended model from scratch: 31.177094401762062 %.

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint  

model_from_scratch = Sequential()

model_from_scratch.add(Conv2D (kernel_size = (2,2), filters = 32, input_shape=train_tensors.shape[1:], activation='relu',data_format="channels_last"))
model_from_scratch.add(MaxPooling2D(pool_size=2, strides=2))
model_from_scratch.add(Conv2D (kernel_size = 2, filters = 64, activation='relu'))
model_from_scratch.add(MaxPooling2D(pool_size = 2, strides=2))
model_from_scratch.add(GlobalAveragePooling2D(data_format=None))
model_from_scratch.add(Dense(109, activation = 'softmax'))
 
model_from_scratch.summary()


from keras.models import Model

model_from_scratch.load_weights('saved_keras_models/aug_model.weights.best.hdf5')


# Creating dictionary that maps layer names to the layers
layer_dict = dict([(layer.name, layer) for layer in model_from_scratch.layers])

# Getting output tensor of the last VGG layer that we want to include
x = layer_dict['max_pooling2d_8'].output

# Stacking a new simple convolutional network on top of it    
#x=GlobalAveragePooling2D()(x)
x = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(filters=64, kernel_size=(2, 2), activation='relu')(x)
x = MaxPooling2D(pool_size=(3, 3))(x)
x = Dropout(0.3)(x)
x = Conv2D(filters=32, kernel_size=(2, 2), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Conv2D(filters=64, kernel_size=(2, 2), activation='relu')(x)
#x = Flatten()(x)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(109, activation='softmax')(x)

# Creating new model. Please note that this is NOT a Sequential() model.
extended_model_from_scratch = Model(input=model_from_scratch.input, output=x)

# We leave the first layers from the model from scratch trainable
for layer in model_from_scratch.layers[:4]:
    layer.trainable = True

extended_model_from_scratch.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 223, 223, 32)      416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 110, 110, 64)      8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 55, 55, 64)        0
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 109)               7085
# ...
# Total params: 15,757
# Trainable params: 15,757
# Non-trainable params: 0
# _________________________________________________________________
# ...
